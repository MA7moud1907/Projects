# %%
import requests 
from bs4 import BeautifulSoup

# %%
url='https://www.yallakora.com/match-center/%d9%85%d8%b1%d9%83%d8%b2-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa#'

# %%
response= requests.get(url)
content=response.content

# %%
soup=BeautifulSoup(content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ar">
# <head>
# <!-- Preloading -->
# <link as="style" href="/Content/StyleOnLoad.css?ver=0.1" rel="preload"/>
# <!-- strat: Chartbeat-->
# <script type="text/javascript">
#         var _sf_startpt = (new Date()).getTime()
#     </script>
# <!-- end: chartbeat-->
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, minimum-scale=1, initial-scale=1" name="viewport"/>
# <!-- Download App Notification -->
# <meta content="app-id=377713182" name="apple-itunes-app" property="apple-itunes-app"/>
# <meta content="app-id=com.inventivotech.yallakora" name="google-play-app" property="google-play-app"/>
# <meta content="max-snippet:-1, max-image-preview:large,max-video-preview:0" name="robots"/>
# <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1" rel="icon" type="image/ico">
# <link href="https://www.yallakora.com//Images/Logo/favicon.ico?ver=1" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://www.yallakora.com//Images/Logo/192x192.png?ver=1" rel="icon" sizes="192x192"/>
# <link href="https://www.yallakora.com//Images/Logo/76x76.png?ver=1" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://www.yallakora.com//Images/Logo/72x72.png?ver=1" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="https://www.yallakora.com//Images/Logo/57x57.png?ver=1" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://www.yallakora.com//Images/Logo/152x152.png?ver=1" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://www.yallakora.com//Images/Logo/144x144.png?ver=1" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://www.yallakora.com//Images/Logo/120x120.png?ver=1" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://www.yallakora.com//Images/Logo/114x114.png?ver=1" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <title> جدول مباريات اليوم | يلاكورة </title>
# <meta content="تابع جدول مواعيد مباريات الكورة اليوم" id="metaKeyword" name="keywords">
# <meta content="تابع جدول مواعيد مباريات الكورة اليوم" id="metaDesc" name="description">
# <link href="https://www.yallakora.com/match-center/مركز-المباريات" id="canonicalUrl" rel="canonical"/>
# <meta content="website" property="og:type">
# <meta content="ar_AR" property="og:locale">
# <meta content="يلاكورة.كوم" property="og:site_name">
# <meta content="index,follow" name="robots">
# <meta content="index,follow" name="googlebot"/>
# <!-- favicons for mobile -->
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="525574017792126" property="fb:app_id">
# <meta content="126773330671427" property="fb:pages">
# <meta content="جدول مباريات اليوم" id="fbTitle" property="og:title"/>
# <meta content="https://www.yallakora.com/match-center/مركز-المباريات" id="fbUrl" property="og:url"/>
# <meta content="تابع جدول مواعيد مباريات الكورة اليوم" id="fbDescription" property="og:description"/>
# <meta content="https://www.yallakora.com/images/SocialShare/yallakora.jpg" data-page-subject="true" id="fbImage" property="og:image"/>
# <meta content="EG" name="twitter:app:country"/>
# <meta content="summary_large_image" name="twitter:card">
# <meta content="@YallakoraNow" name="twitter:site"/>
# <meta content="@YallakoraNow" name="twitter:creator"/>
# <meta content="جدول مباريات اليوم" name="twitter:title"/>
# <meta content="https://www.yallakora.com/match-center/مركز-المباريات" name="twitter:url"/>
# <meta content="تابع جدول مواعيد مباريات الكورة اليوم" id="TwitterDesc" name="twitter:description"/>
# <meta content="https://www.yallakora.com/images/SocialShare/yallakora.jpg" id="TwitterImg" name="twitter:image"/>
# <meta content="#000" name="theme-color"/>
# <link href="/Content/FontFaces.css?ver=0.01" rel="stylesheet" type="text/css"/>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/droidkufi-regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.yallakora.com//fonts/droidkufi-bold.woff2" rel="preload" type="font/woff2"/>
# <!-- Prediction Style -->
# <!-- Yallakora Style -->
# <link href="/Content/Style.min.css?ver=63.57" rel="stylesheet" type="text/css">
# <link href="/Content/Sponsor21.min.css?ver=2.23" rel="stylesheet" type="text/css">
# <link href="/Content/Smartbanner.min.css?ref=0.4" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/Content/GutterStyle.min.css?ver=0.64" rel="stylesheet" type="text/css">
# <link href="/manifest.json" rel="manifest"/>
# <script>
#         var AppPath = 'https://www.yallakora.com/';
#         var IsGoRealTimeApiApplied = 'False';
#         var HubBaseurl = 'https://notificationhub.yallakora.com/signalr/hubs';
#     </script>
# <!--Reference the autogenerated SignalR hub script. -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#             window.googletag = window.googletag || { cmd: [] };
#             googletag.cmd.push(function () {
# 				googletag.defineSlot('/96551095/V3_Yallakora/Desktop/LeaderBoard', [[728, 250], [728, 90], [970, 250], [970, 150]], 'LeaderBoard').addService(googletag.pubads());
# googletag.defineSlot('/96551095/V3_Yallakora/Desktop/MediumRectangle', [[300, 600], [300, 250]], 'MediumRectangle').addService(googletag.pubads());
#
#                 googletag.pubads().enableSingleRequest();
#                 googletag.pubads().collapseEmptyDivs();
#                 googletag.pubads().setTargeting('Yallakora', ["Matchcenter"]);
#                 googletag.enableServices();
#
#             });
# </script>
# <script>
#     (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date(); a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-53252402-1', 'auto');
#
#
#
#
#
#     function TrackEvent(category, action, label) {
#         console.log('Track-> category: ' + category + ' & action: ' + action + ' & label: ' + label);
#         ga('send', {
#             hitType: 'event',
#             eventCategory: category,
#             eventAction: action,
#             eventLabel: label,
#             nonInteraction: true
#         });
#         TrackEventGA4(category, action, label, true);
#     }
#     function TrackEventInteraction(category, action, label) {
#         console.log('Track-> category: ' + category + ' & action: ' + action + ' & label: ' + label);
#         ga('send', {
#             hitType: 'event',
#             eventCategory: category,
#             eventAction: action,
#             eventLabel: label,
#             nonInteraction: false
#         });
#         TrackEventGA4(category, action, label, false);
#     }
#
#     function TrackEventGA4(category, action, label, noninteraction = true) {
#         console.log('TrackGA4-> category: ' + category + ' & action: ' + action + ' & label: ' + label);
#         gtag('event', action, {
#             'event_category': category,
#             'event_label': label,
#             'non_interaction': noninteraction
#         });
#     }
#
#     var pagePath = "";
# </script>
# <!--Google tag(gtag.js)-->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-SS8RTJKBPS"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag() { dataLayer.push(arguments); }
#     gtag('js', new Date());
#
#     gtag('config', 'G-SS8RTJKBPS', {
#         send_page_view: false
#     });
#
# </script>
# <script>
#                     ga('send', 'pageview', { 'page': location.pathname + location.search + location.hash });
#                     pagePath = location.pathname + location.search + location.hash;
#                 </script>
# <script>
#     pagePath = decodeURIComponent(pagePath);
#     console.log(pagePath);
#     console.log('before GA4');
#     gtag('event', 'page_view', {
#         page_location: pagePath,
#         page_path: pagePath,
#         send_to: 'G-SS8RTJKBPS'
#     });
#     console.log('After GA4');
#     //gtag('event', 'page_view', {
#     //   // page_title: pagePath,
#     //    page_location: pagePath
#     //});
#
#
# </script>
# <script>
#     var author = $("#AuthorName").val();
#     if (author != undefined && author != "") {
#         ga('set', 'dimension2', author);
#     } else {
#         author = 'يلاكورة';
#         ga('set', 'dimension2', author);
#     }
#
# </script>
# <!-- BEGIN NARRATIIVE CODE -->
# <!-- COPYRIGHT NARRATIIVE -->
# <!-- BY ADDING THIS TAG TO YOUR WEBSITE YOU AGREE TO ALL POLICIES AND TERMS AVAILABLE AT WWW.NARRATIIVE.COM -->
# <!-- END NARRATIIVE CODE -->
# <!-- chartbeat -->
# <!-- chartbeat -->
# <!-- End Google Tag Manager -->
# <script>
#         $(document).ready(function () {
#             $('.topRead').css({ 'display': 'none' })
#         });
#     </script>
# </link></link></link></meta></meta></meta></meta></meta></meta></meta></meta></meta></link></head>
# <!-- add euroInner in article euro article page-->
# <body class="hideMatchWidget">
# <script src="/bundles/Layout?v=PmS1aZ0gHT6F1kUAmYSxtcWQDeSp-g78IvO7QlBfzOE1"></script>
# <!-- Google Tag Manager (noscript) -->
# <!-- End Google Tag Manager (noscript) -->
# <!-- Yallakora monitor hidden field :Required by admins Bassem khalil:2019-02-19 -->
# <input type="hidden" value="yallakora_gemini.media"/>
# <!-- Download App -->
# <!---------- Header ---------->
# <header>
# <a aria-label="button" class="navBtn" href="#" id="navBtn">
# <span class="menuIcon"></span>
# </a>
# <a aria-label="logo" class="logo" href="https://www.yallakora.com/?nav-logo" title="الرئيسية">
# </a>
# <!---------- Nav ---------->
# <nav class="headerNav">
# <div class="rightMenu">
# <a aria-label="MatchCenter" href="/match-center/%d9%85%d8%b1%d9%83%d8%b2-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa#nav-menu" title="المباريات">المباريات</a>
# <a aria-label="News" href="/newslisting/%d8%a7%d9%84%d8%a3%d8%ae%d8%a8%d8%a7%d8%b1#nav-menu" title="الأخبار">الأخبار</a>
# <a aria-label="Leagues" href="/leagues-cups/%d8%af%d9%88%d8%b1%d9%8a%d8%a7%d8%aa-%d9%88%d8%a8%d8%b7%d9%88%d9%84%d8%a7%d8%aa#nav-menu" title="دوريات وبطولات">دوريات وبطولات</a>
# <a aria-label="Multimedia" href="/multimedia-hp/%d8%b5%d9%88%d8%b1%20%d9%88%20%d9%81%d9%8a%d8%af%d9%8a%d9%88%d9%87%d8%a7%d8%aa#nav-menu" title="مالتيميديا">مالتيميديا</a>
# <a aria-label="Transfers" class="" href="/transfer/%d8%a7%d8%ae%d8%b1-%d8%a7%d9%84%d8%a7%d9%86%d8%aa%d9%82%d8%a7%d9%84%d8%a7%d8%aa/0#nav-menu" title="آخر الانتقالات">آخر الانتقالات</a>
# <a aria-label="esports" class="new" href="https://www.yallakora.com/esports#nav-menu">esports</a>
# <!-- Euro Url -->
# </div>
# <div class="leftMenu">
# <a aria-label="facebook" class="icon-fb" href="https://www.facebook.com/Yallakora" rel="nofollow" target="_blank"></a>
# <a aria-label="Twitter" class="icon-tw" href="https://twitter.com/yallakoranow" rel="nofollow" target="_blank"></a>
# <a aria-label="youtube" class="icon-yt" href="https://www.youtube.com/channel/UC7N7DXktAhFpRpYb3B6Hnxg" rel="nofollow" target="_blank"></a>
# <a aria-label="instagram" class="icon-insta" href="https://www.instagram.com/yallakora/" rel="nofollow" target="_blank"></a>
# <a aria-label="whatsapp" class="icon-whats" href="https://whatsapp.com/channel/0029Va4ypoCEFeXhSKKxp50O" rel="nofollow" target="_blank"></a>
# <a aria-label="search" class="searchBtn icon-search" href="#"><span class="closeSearch"></span></a>
# </div>
# </nav>
# <script type="text/javascript">
#     $(".searchBtn").click(function () {
#         $('body').toggleClass('openSearch');
#         $('body').removeClass('openMenu');
#     });
# </script>
# <!---------- End of Nav ---------->
# <!---------- Menu ---------->
# <div id="Menu"></div>
# <div class="menuDiv">
# <div class="menuContainer">
# <div class="tab">
# <div class="cntr">
# <a aria-label="MatchCenter" class="tabLinks" href="/match-center/%d9%85%d8%b1%d9%83%d8%b2-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa#nav-burgermenu" title="المباريات">المباريات</a>
# <a aria-label="News" class="tabLinks" href="/newslisting/%d8%a7%d9%84%d8%a3%d8%ae%d8%a8%d8%a7%d8%b1#nav-burgermenu" title="الأخبار">الأخبار</a>
# <a aria-label="leagues" class="tabLinks" href="#" id="defaultOpen" onclick="openTab(event, 'tab1')" title="دوريات وبطولات">دوريات وبطولات</a>
# <a aria-label="multimedia" class="tabLinks" href="#" onclick="openTab(event, 'tab2')" title="مالتيميديا">مالتيميديا</a>
# <a aria-label="esports" class="tabLinks" href="/sports-listing/%d8%b1%d9%8a%d8%a7%d8%b6%d8%a7%d8%aa-%d8%a3%d8%ae%d8%b1%d9%89#nav-burgermenu" title="رياضات أخرى"> رياضات أخرى</a>
# <a aria-label="Transfers" class="tabLinks" href="/transfer/%d8%a7%d8%ae%d8%b1-%d8%a7%d9%84%d8%a7%d9%86%d8%aa%d9%82%d8%a7%d9%84%d8%a7%d8%aa/0#nav-burgermenu" title=" آخر الانتقالات"> آخر الانتقالات</a>
# <a aria-label="ProPlayers" class="tabLinks" href="/pro-players/%d8%a3%d8%ae%d8%a8%d8%a7%d8%b1-%d8%a7%d9%84%d9%85%d8%ad%d8%aa%d8%b1%d9%81%d9%8a%d9%86#nav-burgermenu" title="المحترفون"> المحترفون</a>
# <a aria-label="esports" class="tabLinks" href="/esports#nav-burgermenu">Esports</a>
# <div class="linksMenuMobileView">
# <a aria-label="pricing" href="https://gemini.media/pricing#YallakoraF" title="للإعلان معنا">للإعلان معنا</a>
# <a aria-label="policy" href="https://www.yallakora.com/policy" title="سياسة الخصوصية">سياسة الخصوصية</a>
# </div>
# <div class="socialMobileView">
# <a aria-label="facebook" class="icon-fb" href="https://www.facebook.com/Yallakora" rel="nofollow" target="_blank"></a>
# <a aria-label="Twitter" class="icon-tw" href="https://twitter.com/yallakoranow" rel="nofollow" target="_blank"></a>
# <a aria-label="youtube" class="icon-yt" href="https://www.youtube.com/channel/UC7N7DXktAhFpRpYb3B6Hnxg" rel="nofollow" target="_blank"></a>
# <a aria-label="instagram" class="icon-insta" href="https://www.instagram.com/yallakora/" rel="nofollow" target="_blank"></a>
# <a aria-label="whatsapp" class="icon-whats" href="https://whatsapp.com/channel/0029Va4ypoCEFeXhSKKxp50O" rel="nofollow" target="_blank"></a>
# </div>
# </div>
# </div>
# <div class="tabContent Tours" id="tab1">
# <div class="cntr">
# <!-- Tour 1 -->
# <div class="item">
# <div class="title">
# <span>قارية</span>
# </div>
# <ul>
# <li>
# <a aria-label="name" href="/uefa-europa-conference-league/2858/tour-hp/%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%
a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="tabContent WorldCup" id="tab4">
# <div class="cntr">
# <!-- Tour 1 -->
# <div class="item">
# <div class="title">
# <span>كأس العالم</span>
# </div>
# <ul>
# <li>
# <a aria-label="home" href="/afcon/home#nav-burgermenu" title="الرئيسية">الرئيسية</a>
# </li>
# <li>
# <a aria-label="Tour" href="/world-cup/2584/fixtures/%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85#nav-burgermenu" title="المباريات">المباريات</a>
# </li>
# <li>
# <a aria-label="news" href="/category/57/%d8%a7%d8%ae%d8%a8%d8%a7%d8%b1-%d9%85%d8%b5%d8%b1#nav-burgermenu" title="مصر">مصر</a>
# </li>
# <li>
# <a aria-label="news" href="/afcon/2584/tour-news/%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%a3%d9%85%d9%85-%d8%a7%d9%84%d8%a3%d9%81%d8%b1%d9%8a%d9%82%d9%8a%d8%a9#nav-burgermenu" title="">الاخبار</a>
# </li>
# <li>
# <a aria-label="multimedia" href="/afcon/2584/tour-multimedia/%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%a3%d9%85%d9%85-%d8%a7%d9%84%d8%a3%d9%81%d8%b1%d9%8a%d9%82%d9%8a%d8%a9#nav-burgermenu" title="مالتيميديا">مالتيميديا</a>
# </li>
# <li>
# <a aria-label="yk" href="/tvchannel/world-cup-tv/13/-%d9%83%d9%80%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%8a%d9%84%d8%a7-%d9%83%d9%88%d8%b1%d8%a9-tv#nav-burgermenu" title="يلا كورة TV&lt;/">يلا كورة TV</a>
# </li>
# <li>
# <a aria-label="fanzone" href="/world-cup/fan-zone/%d9%85%d9%86%d8%b7%d9%82%d8%a9-%d8%a3%d9%84%d8%b9%d8%a7%d8%a8-%d9%8a%d8%a7%d9%84%d8%a7%d9%83%d9%88%d8%b1%d8%a9#nav-burgermenu" title="ركن الجماهير">ركن الجماهير</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     function openTab(evt, content) {
#         var i, tabcontent, tablinks;
#         tabcontent = document.getElementsByClassName("tabContent");
#         for (i = 0; i < tabcontent.length; i++) {
#             tabcontent[i].style.display = "none";
#         }
#         tablinks = document.getElementsByClassName("tabLinks");
#         for (i = 0; i < tablinks.length; i++) {
#             tablinks[i].className = tablinks[i].className.replace(" active", "");
#         }
#         document.getElementById(content).style.display = "block";
#         evt.currentTarget.className += " active";
#     }
#
#     // Get the element with id="defaultOpen" and click on it
#     document.getElementById("defaultOpen").click();
#
#
#     $(document).ready(function () {
#         function setHeight() {
#             var windowHeight = $(window).height();
#             $('.tab').css('height', windowHeight);                     // 50px is the height of header
#             $('.tabContent').css('height', windowHeight);              // 50px is the height of header
#         };
#         setHeight();
#
#         $(window).resize(function () {
#             setHeight();
#         });
#     });
# </script>
# <!---------- End of Menu ---------->
# <!---------- Search ---------->
# <div class="searchDiv">
# <div class="searchContainer">
# <!-- Search Input -->
# <form id="HeaderSearchForm">
# <div class="search">
# <input class="input" id="HeadertxtSearch" placeholder="بحث" type="search"/>
# <a aria-label="search" class="icon-search HeaderbtnSearch" href="#" id="HeaderbtnSearch"></a>
# <input class="HeaderbtnSearch" style="display:none" type="submit"/>
# </div>
# </form>
# <script>
#
#     $('.HeaderbtnSearch').click(function (e) {
#         e.preventDefault();
#         if ($('#HeadertxtSearch').val() != null && $('#HeadertxtSearch').val() != undefined && $('#HeadertxtSearch').val() != "") {
#             Search($('#HeadertxtSearch').val());
#         }
#     });
#     function Search(searchTxt) {
#         var searchUrl = AppPath + "Search?q=" + searchTxt + "#nav-search";
#         window.location.href = searchUrl;
#     };
# </script>
# </div>
# </div>
# <!---------- End of Search ---------->
# </header>
# <script>
#     $(".navBtn").click(function () {
#         $('body').toggleClass('openMenu');
#         $('body').removeClass('openSearch');
#         ga('send', {
#             hitType: 'event',
#             eventCategory: 'Nav',
#             eventAction: 'Open-Close-Nav',
#             eventLabel: 'BurgerMenuNav'
#         });
#     });
# </script>
# <!---------- End of Header ---------->
# <main class="cd-main-content">
# <div class="container">
# <!-- Sponsor -->
# <script>
#     var AddsenseTimeOut = 5000;
# </script>
# <!-- Sponsor -->
# <!-- Content -->
# <div class="content-wrap" id="content-wrap">
# <div class="content">
# <script src="/Scripts/ArticleAds.js?ver=0.8"></script>
# <script>
#     $(document).ready(function () {
#         $('<script/>', { type: 'text/javascript', src: 'https://srvr.dmvs-apac.com/v2/dm-ce.min.js' }).appendTo('head');
#     });
# </script>
# <!-- Matches Clip -->
# <section class="matchesHp">
# <div class="ttl">
# <div class="matchesTtl">
# <!-- Yesterday -->
# <a class="btn gotoDay yesterday" href="/match-center/%d9%85%d8%b1%d9%83%d8%b2-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa?date=8/26/2023#matchesclipPrev"><span>مباريات الأمس</span></a>
# <!-- All Matches Title -->
# <h4>مباريات اليوم</h4>
# <!-- Tomorrow -->
# <a class="btn gotoDay tomorrow" href="/match-center/%d9%85%d8%b1%d9%83%d8%b2-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa?date=8/28/2023#matchesclipNext"><span>مباريات الغد</span></a>
# </div>
# <a class="allMatchesBtn" href="/match-center/%d9%85%d8%b1%d9%83%d8%b2-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa#matchesclipAll">جميع المباريات<span class="icon-arrow"></span></a>
# </div>
# <!-- Matches Container -->
# <div class="matchesHpCntnr">
# <!-- Matches Slider -->
# <div class="matchesSlider">
# <!-- Match 1 -->
# <div class="done matchesSliderLi" livescorematchid="89809">
# <a href="/fiba-basketball-world-cup/2819/match/89809/%d8%a7%d9%84%d8%ac%d8%a8%d9%84-%d8%a7%d9%84%d8%a7%d8%b3%d9%88%d8%af-%d9%85%d8%b5%d8%b1-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#matchesclip">
# <div class="tourName">
# كأس العالم لكرة السلة                                    </div>
# <div class="teamA">
# <img alt="الجبل الاسود" class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2023\8\17\montenegro12023_8_17_0_6.jpg" width="26"/>
# <p>
#                                             الجبل الاسود
#                                         </p>
# </div>
# <div class="resultDiv">
# <div class="matchResult">
# <span class="result LiveTeamA">89</span>
# <span class="result LiveTeamB">74</span>
# </div>
# <div class="matchStatus">
# <span class="status"></span>
# <span class="time">11:45</span>
# </div>
# </div>
# <div class="teamB">
# <img alt="مصر" class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2022\8\3\egypt12022_8_3_16_40.jpg" width="26"/>
# <p>
#                                             مصر
#                                         </p>
# </div>
# <div class="clear">
# </div>
# </a>
# </div>
# <!-- Match 1 -->
# <div class="done matchesSliderLi" livescorematchid="89259">
# <a href="/epl/2829/match/89259/%d8%b4%d9%8a%d9%81%d9%8a%d9%84%d8%af-%d9%8a%d9%88%d9%86%d8%a7%d9%8a%d8%aa%d8%af-%d9%85%d8%a7%d9%86%d8%b4%d8%b3%d8%aa%d8%b1-%d8%b3%d9%8a%d8%aa%d9%8a-%d8%a7%d9%84%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%d8%a5%d9%86%d8%ac%d9%84%d9%8a%d8%b2%d9%8a#matchesclip">
# <div class="tourName">
# الدوري الإنجليزي                                    </div>
# <div class="teamA">
# <img alt="شيفيلد يونايتد" class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2018\9\10\SheffieldUnited2018_9_10_13_32.jpg" width="26"/>
# <p>
#                                             شيفيلد يونايتد
#                                         </p>
# </div>
# <div class="resultDiv">
# <div class="matchResult">
# <span class="result LiveTeamA">1</span>
# <span class="result LiveTeamB">2</span>
# </div>
# <div class="matchStatus">
# <span class="status"></span>
# <span class="time">16:00</span>
# </div>
# </div>
# <div class="teamB">
# <img alt="مانشستر سيتي" class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2018\7\29\ManchesterCity2018_7_29_15_27.jpg" width="26"/>
# <p>
#                                             مانشستر سيتي
#                                         </p>
# </div>
# <div class="clear">
# </div>
# </a>
# </div>
# <!-- Match 1 -->
# <div class="done matchesSliderLi" livescorematchid="89265">
# <a href="/epl/2829/match/89265/%d9%86%d9%8a%d9%88%d9%83%d8%a7%d8%b3%d9%84-%d9%84%d9%8a%d9%81%d8%b1%d8%a8%d9%88%d9%84-%d8%a7%d9%84%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%d8%a5%d9%86%d8%ac%d9%84%d9%8a%d8%b2%d9%8a#matchesclip">
# <div class="tourName">
# الدوري الإنجليزي                                    </div>
# <div class="teamA">
# <img alt="نيوكاسل" class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2018\7\29\NewcastleUnited2018_7_29_15_27.jpg" width="26"/>
# <p>
#                                             نيوكاسل
#                                         </p>
# </div>
# <div class="resultDiv">
# <div class="matchResult">
# <span class="result LiveTeamA">1</span>
# <span class="result LiveTeamB">2</span>
# </div>
# <div class="matchStatus">
# <span class="status"></span>
# <span class="time">18:30</span>
# </div>
# </div>
# <div class="teamB">
# <img alt="ليفربول" class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2018\7\29\Liverpool2018_7_29_15_27.jpg" width="26"/>
# <p>
#                                             ليفربول
#                                         </p>
# </div>
# <div class="clear">
# </div>
# </a>
# </div>
# <!-- Match 1 -->
# <div class="done matchesSliderLi" livescorematchid="89341">
# <a href="/la-liga/2833/match/89341/%d9%81%d9%8a%d8%a7%d8%b1%d9%8a%d8%a7%d9%84-%d8%a8%d8%b1%d8%b4%d9%84%d9%88%d9%86%d8%a9--%d8%a7%d9%84%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%d8%a5%d8%b3%d8%a8%d8%a7%d9%86%d9%8a#matchesclip">
# <div class="tourName">
# الدوري الإسباني                                    </div>
# <div class="teamA">
# <img alt="فياريال" class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2018\7\29\Villareal2018_7_29_14_53.jpg" width="26"/>
# <p>
#                                             فياريال
#                                         </p>
# </div>
# <div class="resultDiv">
# <div class="matchResult">
# <span class="result LiveTeamA">3</span>
# <span class="result LiveTeamB">4</span>
# </div>
# <div class="matchStatus">
# <span class="status"></span>
# <span class="time">18:30</span>
# </div>
# </div>
# <div class="teamB">
# <img alt="برشلونة " class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2018\7\29\Barcelona2018_7_29_14_44.jpg" width="26"/>
# <p>
#                                             برشلونة
#                                         </p>
# </div>
# <div class="clear">
# </div>
# </a>
# </div>
# <!-- Match 1 -->
# <div class="done matchesSliderLi" livescorematchid="89760">
# <a href="/bundesliga/2837/match/89760/%d9%85%d8%a7%d9%8a%d9%86%d8%b2-%d8%a2-%d9%81%d8%b1%d8%a7%d9%86%d9%83%d9%81%d9%88%d8%b1%d8%aa--%d8%a7%d9%84%d8%af%d9%88%d8%b1%d9%8a-%d8%a7%d9%84%d8%a3%d9%84%d9%85%d8%a7%d9%86%d9%8a#matchesclip">
# <div class="tourName">
# الدوري الألماني                                    </div>
# <div class="teamA">
# <img alt="ماينز" class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2018\7\29\Mainz2018_7_29_16_7.jpg" width="26"/>
# <p>
#                                             ماينز
#                                         </p>
# </div>
# <div class="resultDiv">
# <div class="matchResult">
# <span class="result LiveTeamA">1</span>
# <span class="result LiveTeamB">1</span>
# </div>
# <div class="matchStatus">
# <span class="status"></span>
# <span class="time">16:30</span>
# </div>
# </div>
# <div class="teamB">
# <img alt="آ. فرانكفورت " class="" height="26" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//80/\2018\7\29\Frankfurt2018_7_29_16_5.jpg" width="26"/>
# <p>
#                                             آ. فرانكفورت
#                                         </p>
# </div>
# <div class="clear">
# </div>
# </a>
# </div>
# </div>
# </div>
# <a class="allMatchesBtn mob" href="/match-center/%d9%85%d8%b1%d9%83%d8%b2-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa#matchesclipAll">جميع المباريات<span class="icon-arrow"></span></a>
# </section>
# <script>
#     $('.matchesSlider').flickity({
#         // options
#         cellAlign: 'center',
#         contain: true,
#         freeScroll: true,
#         prevNextButtons: true,
#         accessibility: false,
#         pageDots: false,
#         lazyLoad: true,
#         groupCells: true,
#     });
# </script>
# <script>
#     $(".matchesHp .flickity-button.previous").click(function () {
#         //ga('send', {
#         //    hitType: 'event',
#         //    eventCategory: 'MatchesClip',
#         //    eventAction: 'Click',
#         //    eventLabel: 'Prev-Arrow'
#         //});
#         TrackEvent('MatchesClip', 'Click', 'Prev-Arrow');
#
#     })
#     $(".matchesHp .flickity-button.next").click(function () {
#         //ga('send', {
#         //    hitType: 'event',
#         //    eventCategory: 'MatchesClip',
#         //    eventAction: 'Click',
#         //    eventLabel: 'Next-Arrow'
#         //});
#         TrackEvent('MatchesClip', 'Click', 'Next-Arrow');
#
#
#     })
# </script>
# <section class="proPlayer mainTour matchcenter">
# <div class="pagecnts">
# <!-- right side-->
# <div class="rightside">
# <div class="maxWidth">
# <!-- Matches Center -->
# <section class="matchesCenter">
# <div class="matchesCenterTitle">
# <h1>جميع المباريات</h1>
# <div class="ttlOptions">
# <!-- Dropdown -->
# <div class="toursDropdown cd-select cd-filters">
# <select class="filter tourFilter" id="selectThis" name="selectThis">
# <option selected="" value="0">كل البطولات</option>
# <option value="2819">كأس العالم لكرة السلة</option>
# <option value="2829">الدوري الإنجليزي</option>
# <option value="2833">الدوري الإسباني</option>
# <option value="2855">البطولة العربية للأندية لكرة اليد</option>
# <option value="2836">الدوري الإيطالي</option>
# <option value="2837">الدوري الألماني</option>
# <option value="2838">الدوري الفرنسي</option>
# <option value="2839">دوري أبطال إفريقيا</option>
# <option value="2840">الكونفيدرالية الإفريقية</option>
# <option value="2845">الدوري التركي</option>
# <option value="2853">الدوري التونسي</option>
# <option value="2851">الدوري المغربي</option>
# <option value="2843">الدوري البرتغالي</option>
# <option value="2848">دوري نجوم قطر</option>
# <option value="2852">الدوري الإماراتي</option>
# </select>
# </div>
# <!-- Date Picker -->
# <div class="dateDiv">
# <a class="dateBtn icon-date"></a>
# <div class="ui-datepicker" id="txtDatepicker">
# </div>
# <script src="/Scripts/jqueryUI-1.10.2.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var txId = '#txtDatepicker';
#     $(txId).datepicker({
#
#         buttonImageOnly: true,
#         showOn: 'both',
#         closeText: 'X',
#         dateFormat: 'yy-mm-dd',
#         monthNames: ['يناير', 'فبراير', 'مارس', 'إبريل', 'مايو', 'يونيو', 'يوليو', 'أغسطس', 'سبتمبر', 'أكتوبر', 'نوفمبر', 'ديسمبر'],
#         dayNames: ['الأحد', 'الإثنين', 'الثلاثاء', 'الأربعاء', 'الخميس', 'الجمعة', 'السبت'],
#         dayNamesMin: ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat'],
#         nextText: '',
#         prevText: '',
#         gotoCurrent: 'true',
#         onSelect: function (date) {
#             window.location.href = '/match-center/مركز-المباريات' + "?date=" + date +"#days";
#         }
#         //beforeShow: function (textbox, instance) {
#         //    $('.cd-main-content').append($('#ui-datepicker-div'));
#         //    $('#ui-datepicker-div').hide();
#         //},
#     });
# </script>
# </div>
# </div>
# </div>
# <div>
# <!-- Day -->
# <div class="dayName">
# <h2>
#                 مباريات يوم
#                 الأحد
#                 <span>27 أغسطس 2023</span>
# </h2>
# </div>
# <!-- Number of Tours / Matches -->
# <div class="toursMatchesNum">
# <p><span class="matchesCount">0</span>مباراة</p>
# <p><span>15</span>بطولات</p>
# </div>
# </div>
# <div class="matchCenterDays">
# <div class="daysSlider tab">
# <button class="dayTabLinks" date="2/26/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/27/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/28/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/1/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/2/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/3/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/4/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/5/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/6/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/7/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/8/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/9/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/10/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/11/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/12/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/13/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/14/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/15/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/16/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/17/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/18/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/19/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/20/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/21/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/22/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/23/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/24/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/25/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/26/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/27/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/28/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/29/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/30/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# ...
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--content {
#                 width: 100%;
#                 margin: 0 20px;
#             }
#
#             #izooto-optin .izooto-optin--content .izooto-optin--title span {
#                 color: #ffffff;
#                 font-size: 18px;
#                 word-break: break-word;
#                 font-weight: 400;
#                 font-family: droidLight, Arial;
#                 margin-bottom: 6px;
#             }
#
#             #izooto-optin .izooto-optin--content .izooto-optin--message span {
#                 color: #ffffffa6;
#                 font-size: 13px;
#                 font-weight: 400;
#                 font-family: droidLight, Arial
#             }
#
#             #izooto-optin .izooto-optin--ctas-container {
#                 margin: 0 10px;
#             }
#
#                 #izooto-optin .izooto-optin--ctas-container .izooto-optin--cta {
#                     margin: 0 5px;
#                     box-sizing: border-box;
#                     text-transform: unset;
#                     position: relative;
#                     -webkit-user-select: none;
#                     -moz-user-select: none;
#                     -ms-user-select: none;
#                     user-select: none;
#                     cursor: pointer;
#                     outline: 0;
#                     border: none;
#                     -webkit-tap-highlight-color: transparent;
#                     display: inline-block;
#                     white-space: nowrap;
#                     text-decoration: none;
#                     font-size: 13px;
#                     vertical-align: baseline;
#                     text-align: center;
#                     line-height: 36px;
#                     border-radius: 4px;
#                     padding: 0 13px;
#                     min-width: 100px;
#                     max-width: 175px;
#                     overflow: hidden;
#                     text-overflow: ellipsis;
#                     font-family: droidLight, Arial
#                 }
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--ctas-container .izooto-optin--cta.izooto-optin--cta-later {
#                 background-color: #ffffff !important;
#                 color: #1d1d1d !important;
#             }
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--ctas-container .izooto-optin--cta.izooto-optin--cta-allow {
#                 background-color: #0277bd !important;
#                 color: #ffffff !important;
#                 box-shadow: 0 3px 1px -2px rgba(0, 0, 0, .2), 0 2px 2px 0 rgba(0, 0, 0, .14), 0 1px 5px 0 rgba(0, 0, 0, .12)
#             }
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper {
#                 position: absolute;
#                 width: auto;
#                 line-height: 1
#             }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper.izooto-optin--branding-wrapper-sticky-header {
#                     right: 5px;
#                     bottom: 3px
#                 }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper .izooto-optin--branding-text {
#                     text-decoration: none;
#                     font-size: 11px;
#                     font-weight: 400;
#                     font-family: droidLight, Arial;
#                     color: #fff
#                 }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper .izooto-optin--izooto-txt {
#                     color: #c2ccec
#                 }
#
#             @media screen and (max-width:640px) {
#                 #izooto-optin .iz-row--mobile-col {
#                     flex-direction: column
#                 }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--content {
#                     margin: 0 10px;
#                 }
#
#                 #izooto-optin .izooto-optin--content .izooto-optin--title span {
#                     font-size: 16px
#                 }
#
#                 #izooto-optin .izooto-optin--content .izooto-optin--message span {
#                     font-size: 13px;
#                     margin-top: 5px
#                 }
#
#                 #izooto-optin .izooto-optin--ctas-container-for-mob {
#                     margin-top: 15px;
#                     margin-bottom: 10px
#                 }
#
#                 #izooto-optin .izooto-optin--ctas-container .izooto-optin--cta {
#                     min-width: 85px;
#                     max-width: 50%
#                 }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper.izooto-optin--branding-wrapper-sticky-header {
#                     right: 15.2px;
#                     bottom: 5px
#                 }
#             }
#         </style>
# <div class="izooto-optin--sticky-header izooto-optin--preview-container" dir="auto" id="izooto-optin">
# <div class="iz-row iz-row--space-btwn iz-row--mobile-col">
# <div class="iz-row iz-row--space-btwn" id="izooto-optin-icon-content-container">
# <div class="iz-col iz-col--content-center izooto-optin--icon-wrapper">
# <img alt="Default Opt-in Icon" class="izooto-optin--icon" height="40" src="https://cdnimg.izooto.com/icons/7/bell-icon.png" width="40"/>
# </div>
# <div class="izooto-optin--content">
# <div class="izooto-optin--title">
# <span class="izooto-optin--line-clamp izooto-optin--line-clamp-2">خدمة الإشعارات</span>
# </div>
# <div class="izooto-optin--message mt-5">
# <span class="izooto-optin--line-clamp izooto-optin--line-clamp-2">تلقى آخر الأخبار والمستجدات من موقع يلاكورة</span>
# </div>
# </div>
# </div>
# <div class="iz-col">
# <div class="iz-row iz-row--flex-end izooto-optin--ctas-container izooto-optin--ctas-container-for-mob">
# <button class="izooto-optin--cta izooto-optin--cta-later" onclick="CloseDialog();">لاحقا</button>
# <button class="izooto-optin--cta izooto-optin--cta-allow" onclick="OpenDialog()">اشترك</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#         if (Notification.permission !== "granted" && General.GetCookie('DismissNotification') !== 'true') {
#             $('#izmiddle-box').show();
#
#             function OpenDialog() {
#                 window._izq.push(['triggerPrompt']);
#                 $('#izmiddle-box').addClass('hide');
#             }
#             function CloseDialog() {
#                 General.SetCookie('DismissNotification', 'true', 7);
#                 $('#izmiddle-box').addClass('hide');
#             }
#         }
#
#         else {
#             $('#izmiddle-box').hide();
#         }
#     </script>
# <!-- Lazyload -->
# <script src="/Scripts/lazyload.min.js" type="text/javascript"></script>
# <!--Tracking event for video compagins-->
# <script>
#         $('.goToVideo').click(function () {
#             //ga('send', {
#             //    hitType: 'event',
#             //    eventCategory: 'campaign',
#             //    eventAction: 'play-video',
#             //    eventLabel: 'pepsi-Campaign'
#             //});
#             TrackEvent('campaign', 'play-video', 'pepsi-Campaign');
#
#         });
#         $('#showcase_expandable_btn').hover(function () {
#             //ga('send', {
#             //    hitType: 'event',
#             //    eventCategory: 'campaign',
#             //    eventAction: 'play-video',
#             //    eventLabel: 'pepsi-Campaign'
#             //});
#             TrackEvent('campaign', 'play-video', 'pepsi-Campaign');
#
#
#             console.log("mouse hovered to mo salah showcase ad");
#         });
#         if ('False'=='True') {
#             $('.Mobile-SC').click(function () {
#                 //ga('send', {
#                 //    hitType: 'event',
#                 //    eventCategory: 'campaign',
#                 //    eventAction: 'click-sc-mob',
#                 //    eventLabel: 'Beyti-click-sc-mob'
#                 //});
#                 TrackEvent('campaign', 'click-sc-mob', 'Beyti-click-sc-mob');
#
#             });
#         }
#         else {
#             $('.Desktop_SC').hover(function () {
#                 //ga('send', {
#                 //    hitType: 'event',
#                 //    eventCategory: 'campaign',
#                 //    eventAction: 'hover-desktop-sc',
#                 //    eventLabel: 'Beyti-hover-desktop-sc'
#                 //});
#                 TrackEvent('campaign', 'hover-desktop-sc', 'Beyti-hover-desktop-sc');
#
#
#             });
#             $('.Desktop-OTP').hover(function () {
#                 //ga('send', {
#                 //    hitType: 'event',
#                 //    eventCategory: 'campaign',
#                 //    eventAction: 'hover-desktop-otp',
#                 //    eventLabel: 'Beyti-hover-desktop-otp'
#                 //});
#                 TrackEvent('campaign', 'hover-desktop-otp', 'Beyti-hover-desktop-otp');
#
#
#             });
#         }
#         </script>
# <script>
#             $('body').on('click', '.sp-wi-item a', function () {
#                 // do something
#                 console.log('Speakol Item is clicked');
#                 //ga('send', {
#                 //    hitType: 'event',
#                 //    eventCategory: 'Speakol-Tracking',
#                 //    eventAction: 'Open-Speakol-Link',
#                 //    eventLabel: 'Open-Speakol-Link'
#                 //});
#                 TrackEvent('Speakol-Tracking', 'Open-Speakol-Link', 'Open-Speakol-Link');
#
#             });
#         </script>
# <script>
#            function trackPageView(hashTag) {
#                 var isMobile = 'False';
#                 if (isMobile == "True") {
#                     isMobile = "/mobile/";
#                 }
#                 else {
#                     isMobile = "";
#                 }
#
#                 var curUrl = isMobile + location.pathname + location.search;
#                 if (hashTag != '' && hashTag != undefined) {
#                     curUrl += hashTag;
#                 }
#                 else {
#                     curUrl += location.hash
#                 }
#                 try {
#                     //For google analytics
#                     ga('send', 'pageview', curUrl);
#                     //console.log("go tacking " + curUrl);
#
#                 } catch (ex) {
#                     console.log(ex.message);
#                }
#                trackPageViewGA4(hashTag);
#         }
#         function trackPageViewGA4(hashTag) {
#                 var isMobile = 'False';
#                 if (isMobile == "True") {
#                     isMobile = "/mobile/";
#                 }
#                 else {
#                     isMobile = "";
#                 }
#
#                 var curUrl = isMobile + location.pathname + location.search;
#                 if (hashTag != '' && hashTag != undefined) {
#                     curUrl += hashTag;
#                 }
#                 else {
#                     curUrl += location.hash
#             }
#             curUrl = decodeURIComponent(curUrl);
#                 try {
#                     //For google analytics
#                     ga('send', 'pageview', curUrl);
#                     gtag('event', 'page_view', {
#                         page_location: curUrl,
#                         page_path: curUrl,
#                         send_to: 'G-SS8RTJKBPS'
#                     })
#                     console.log("GA4 track page view:  " + curUrl);
#
#                 } catch (ex) {
#                     console.log(ex.message);
#                 }
#             }
#         </script>
# <!--lotame-->
# <link rel ="preconnect"="" href="https://tags.crwdcntrl.net">
# <link rel ="preconnect"="" href="https://bcp.crwdcntrl.net">
# <link rel ="dns-prefetch"="" href="https://tags.crwdcntrl.net">
# <link rel ="dns-prefetch"="" href="https://bcp.crwdcntrl.net">
# <script>
#                     ! function () {
#                         window.googletag = window.googletag || {};
#                         window.googletag.cmd = window.googletag.cmd || [];
#                         var targetingKey = 'lotame';
#                         var lotameClientId = '15758';
#                         var audLocalStorageKey = 'lotame_' + lotameClientId + '_auds';
#
#                         // Immediately get audiences from local storage and get them loaded
#                         try {
#                             var storedAuds = window.localStorage.getItem(audLocalStorageKey) || '';
#
#                             if (storedAuds) {
#                                 googletag.cmd.push(function () {
#                                     window.googletag.pubads().setTargeting(targetingKey, storedAuds.split(','));
#                                 });
#                             }
#                         } catch (e) {
#                         }
#
#                         // Callback when targeting audience is ready to push latest audience data
#                         var audienceReadyCallback = function (profile) {
#
#                             // Get audiences as an array
#                             var lotameAudiences = profile.getAudiences() || [];
#
#                             // Set the new target audiences for call to Google
#                             googletag.cmd.push(function () {
#                                 window.googletag.pubads().setTargeting(targetingKey, lotameAudiences);
#                             });
#                         };
#
#                         // Lotame Config
#                         var lotameTagInput = {
#                             data: {},
#                             config: {
#                                 clientId: Number(lotameClientId),
#                                 audienceLocalStorage: audLocalStorageKey,
#                                 onProfileReady: audienceReadyCallback
#                             }
#                         };
#
#                         // Lotame initialization
#                         var lotameConfig = lotameTagInput.config || {};
#                         var namespace = window['lotame_' + lotameConfig.clientId] = {};
#                         namespace.config = lotameConfig;
#                         namespace.data = lotameTagInput.data || {};
#                         namespace.cmd = namespace.cmd || [];
#                     }();
#                 </script>
# <script async="" src="https://tags.crwdcntrl.net/lt/c/15758/lt.min.js"></script>
# <script type="application/ld+json">
#         {
#         "@context" : "http://schema.org",
#         "@type" : "Organization",
#         "name" : "Yallakora",
#         "url" : "https://www.yallakora.com/",
#         "logo": "https://www.yallakora.com//Images/Logo/192x192.png?ver=1",
#         "sameAs" : [
#         "https://www.facebook.com/Yallakora/",
#         "https://twitter.com/Yallakoranow",
#         "https://www.youtube.com/channel/UC7N7DXktAhFpRpYb3B6Hnxg",
#         "https://www.instagram.com/yallakoraofficial/"
#         ]
#         }
#     </script>
# <!-- IP2Location Script -->
# <!-- GTag -->
# <!--izooto-->
# <script>
#             window._izq = window._izq || []; window._izq.push(["init", { "auto_prompt": false }]);
#         </script>
# <script src="https://cdn.izooto.com/scripts/a0e1f72be7d69fe7b47acade32a261ad5c080d74.js">
# </script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'7fd6a4871d410db5',t:'MTY5MzE2MzcyMS41MjAwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></link rel></link rel></link rel></link rel></body>
# </html>

# %%
championships=soup.find_all('div',class_='matchCard')

# %%
championships
# Out:
# [<div class="2819 matchCard matchesList">
#  <div class="title">
#  <a class="tourTitle" href="/fiba-basketball-world-cup/2819/tour-hp/%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails">
#  <div class="imgCntnr">
#  <img alt="كأس العالم لكرة السلة" enname="FIBA Basketball World Cup" src="https://www.yallakora.com/pictures/Tourlogo/fiba-cup116-8-2023-21-1-3.png"/>
#  </div>
#  <h2>
#                                          كأس العالم لكرة السلة
#                                      </h2>
#  </a>
#  <div class="links">
#  <a class="more" href="/fiba-basketball-world-cup/2819/tour-news/%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#Matches-newslisting" title="أخبار">أخبار</a>
#  <a class="more" href="/fiba-basketball-world-cup/2819/tour-multimedia/%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9)#Matches-Multimedia" title="مالتيميديا">مالتيميديا</a>
#  <a class="more" href="/fiba-basketball-world-cup/2819/group-standing/%d8%aa%d8%b1%d8%aa%d9%8a%d8%a8-%d8%a7%d9%84%d9%81%d8%b1%d9%82-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#Matches-Standing" title="ترتيب الفرق">ترتيب الفرق</a>
#  <a class="more" href="/fiba-basketball-world-cup/2819/fixtures/%d9%86%d8%aa%d8%a7%d8%a6%d8%ac-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#Matches-Fixtures" title="نتائج المباريات"> نتائج المباريات</a>
#  <div class="more moreMenuBtn">
#  <span>المزيد</span>
#  <div class="moreMenu">
#  <a class="moreBtnMenu" href="/fiba-basketball-world-cup/2819/tour-news/%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#Matches-newslisting" title="أخبار">أخبار</a>
#  <a class="moreBtnMenu" href="/fiba-basketball-world-cup/2819/tour-multimedia/%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9)#Matches-Multimedia" title="مالتيميديا">مالتيميديا</a>
#  <a class="moreBtnMenu" href="/fiba-basketball-world-cup/2819/standing/%d8%aa%d8%b1%d8%aa%d9%8a%d8%a8-%d8%a7%d9%84%d9%81%d8%b1%d9%82-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9)#Matches-Standing" title="ترتيب الفرق">ترتيب الفرق</a>
#  <a class="moreBtnMenu" href="/fiba-basketball-world-cup/2819/fixtures/%d9%86%d8%aa%d8%a7%d8%a6%d8%ac-%d8%a7%d9%84%d9%85%d8%a8%d8%a7%d8%b1%d9%8a%d8%a7%d8%aa-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#Matches-Fixtures" title="نتائج المباريات"> نتائج المباريات</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <ul>
#  <!-- Match 1 -->
#  <li class="item finish" livescorematchid="89827">
#  <a href="/fiba-basketball-world-cup/2819/match/89827/%d8%a5%d9%8a%d8%b7%d8%a7%d9%84%d9%8a%d8%a7-%d8%a7%d9%84%d8%af%d9%88%d9%85%d9%8a%d9%86%d9%8a%d9%83%d8%a7%d9%86-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails" title="تفاصيل المباراة">
#  <div class="allData">
#  <!-- Match Top Data -->
#  <div class="channel icon-channel">بى ان سبورت 4 HD</div>
#  <!--Time & Status-->
#  <div class="topData">
#  <div class="date">الجولة الثانية</div>
#  <div class="matchStatus">
#  <span>انتهت</span>
#  </div>
#  </div>
#  <!--Teams-->
#  <div class="teamCntnr">
#  <div class="teamsData">
#  <!-- Team A -->
#  <div class="teams teamA">
#  <img alt="إيطاليا" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\16\italy12023_8_16_23_19.jpg"/>
#  <p>إيطاليا</p>
#  </div>
#  <!-- Match Result -->
#  <div class="MResult">
#  <span class="score">82</span>
#  <span>-</span>
#  <span class="score">87</span>
#  <span class="time">11:00</span>
#  </div>
#  <!-- Team B -->
#  <div class="teams teamB">
#  <img alt="الدومينيكان" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\16\dominican12023_8_16_22_13.jpg"/>
#  <p>الدومينيكان</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="leftCol">
#  <a class="button details" href="/fiba-basketball-world-cup/2819/match/89827/%d8%a5%d9%8a%d8%b7%d8%a7%d9%84%d9%8a%d8%a7-%d8%a7%d9%84%d8%af%d9%88%d9%85%d9%8a%d9%86%d9%8a%d9%83%d8%a7%d9%86-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails">التفاصيل</a>
#  </div>
#  </li>
#  <li class="item finish" livescorematchid="89833">
#  <a href="/fiba-basketball-world-cup/2819/match/89833/%d8%a3%d8%b3%d8%aa%d8%b1%d8%a7%d9%84%d9%8a%d8%a7-%d8%a3%d9%84%d9%85%d8%a7%d9%86%d9%8a%d8%a7-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails" title="تفاصيل المباراة">
#  <div class="allData">
#  <!-- Match Top Data -->
#  <div class="channel icon-channel">بى ان سبورت 3 HD</div>
#  <!--Time & Status-->
#  <div class="topData">
#  <div class="date">الجولة الثانية</div>
#  <div class="matchStatus">
#  <span>انتهت</span>
#  </div>
#  </div>
#  <!--Teams-->
#  <div class="teamCntnr">
#  <div class="teamsData">
#  <!-- Team A -->
#  <div class="teams teamA">
#  <img alt="أستراليا" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\17\australia12023_8_17_17_32.jpg"/>
#  <p>أستراليا</p>
#  </div>
#  <!-- Match Result -->
#  <div class="MResult">
#  <span class="score
d8%a7-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails">التفاصيل</a>
#  </div>
#  </li>,
#  <li class="item finish" livescorematchid="89834">
#  <a href="/fiba-basketball-world-cup/2819/match/89834/%d8%a7%d9%84%d9%8a%d8%a7%d8%a8%d8%a7%d9%86-%d9%81%d9%86%d9%84%d9%86%d8%af%d8%a7-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails" title="تفاصيل المباراة">
#  <div class="allData">
#  <!-- Match Top Data -->
#  <div class="channel icon-channel">بى ان سبورت HD</div>
#  <!--Time & Status-->
#  <div class="topData">
#  <div class="date">الجولة الثانية</div>
#  <div class="matchStatus">
#  <span>انتهت</span>
#  </div>
#  </div>
#  <!--Teams-->
#  <div class="teamCntnr">
#  <div class="teamsData">
#  <!-- Team A -->
#  <div class="teams teamA">
#  <img alt="اليابان" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\17\japan12023_8_17_17_35.jpg"/>
#  <p>اليابان</p>
#  </div>
#  <!-- Match Result -->
#  <div class="MResult">
#  <span class="score">98</span>
#  <span>-</span>
#  <span class="score">88</span>
#  <span class="time">15:10</span>
#  </div>
#  <!-- Team B -->
#  <div class="teams teamB">
#  <img alt="فنلندا" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\17\finland12023_8_17_16_30.jpg"/>
#  <p>فنلندا</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="leftCol">
#  <a class="button details" href="/fiba-basketball-world-cup/2819/match/89834/%d8%a7%d9%84%d9%8a%d8%a7%d8%a8%d8%a7%d9%86-%d9%81%d9%86%d9%84%d9%86%d8%af%d8%a7-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails">التفاصيل</a>
#  </div>
#  </li>,
#  <li class="item finish" livescorematchid="89810">
#  <a href="/fiba-basketball-world-cup/2819/match/89810/%d9%84%d9%8a%d8%aa%d9%88%d8%a7%d9%86%d9%8a%d8%a7-%d8%a7%d9%84%d9%85%d9%83%d8%b3%d9%8a%d9%83-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails" title="تفاصيل المباراة">
#  <div class="allData">
#  <!-- Match Top Data -->
#  <div class="channel icon-channel">بى ان سبورت 7 HD</div>
#  <!--Time & Status-->
#  <div class="topData">
#  <div class="date">الجولة الثانية</div>
#  <div class="matchStatus">
#  <span>انتهت</span>
#  </div>
#  </div>
#  <!--Teams-->
#  <div class="teamCntnr">
#  <div class="teamsData">
#  <!-- Team A -->
#  <div class="teams teamA">
#  <img alt="ليتوانيا" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\17\lithuania12023_8_17_0_14.jpg"/>
#  <p>ليتوانيا</p>
#  </div>
#  <!-- Match Result -->
#  <div class="MResult">
#  <span class="score">96</span>
#  <span>-</span>
#  <span class="score">66</span>
#  <span class="time">15:30</span>
#  </div>
#  <!-- Team B -->
#  <div class="teams teamB">
#  <img alt="المكسيك" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\17\mexico12023_8_17_0_0.jpg"/>
#  <p>المكسيك</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="leftCol">
#  <a class="button details" href="/fiba-basketball-world-cup/2819/match/89810/%d9%84%d9%8a%d8%aa%d9%88%d8%a7%d9%86%d9%8a%d8%a7-%d8%a7%d9%84%d9%85%d9%83%d8%b3%d9%8a%d9%83-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails">التفاصيل</a>
#  </div>
#  </li>,
#  <li class="item finish" livescorematchid="89840">
#  <a href="/fiba-basketball-world-cup/2819/match/89840/%d9%81%d8%b1%d9%86%d8%b3%d8%a7-%d9%84%d8%a7%d8%aa%d9%81%d9%8a%d8%a7-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails" title="تفاصيل المباراة">
#  <div class="allData">
#  <!-- Match Top Data -->
#  <div class="channel icon-channel">بى ان سبورت 5 HD</div>
#  <!--Time & Status-->
#  <div class="topData">
#  <div class="date">الجولة الثانية</div>
#  <div class="matchStatus">
#  <span>انتهت</span>
#  </div>
#  </div>
#  <!--Teams-->
#  <div class="teamCntnr">
#  <div class="teamsData">
#  <!-- Team A -->
#  <div class="teams teamA">
#  <img alt="فرنسا" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\17\france12023_8_17_19_23.jpg"/>
#  <p>فرنسا</p>
#  </div>
#  <!-- Match Result -->
#  <div class="MResult">
#  <span class="score">86</span>
#  <span>-</span>
#  <span class="score">88</span>
#  <span class="time">16:30</span>
#  </div>
#  <!-- Team B -->
#  <div class="teams teamB">
#  <img alt="لاتفيا" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\17\latvia12023_8_17_19_13.jpg"/>
#  <p>لاتفيا</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>
#  <div class="leftCol">
#  <a class="button details" href="/fiba-basketball-world-cup/2819/match/89840/%d9%81%d8%b1%d9%86%d8%b3%d8%a7-%d9%84%d8%a7%d8%aa%d9%81%d9%8a%d8%a7-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails">التفاصيل</a>
#  </div>
#  </li>]

# %%
for i in range(len(championships)):
    print(championships[i].contents[1].find('h2').text.strip())
# Out:
# كأس العالم لكرة السلة
# الدوري الإنجليزي
# الدوري الإسباني
# البطولة العربية للأندية لكرة اليد
# الدوري الإيطالي
# الدوري الألماني
# الدوري الفرنسي
# دوري أبطال إفريقيا
# الكونفيدرالية الإفريقية
# الدوري التركي
# الدوري التونسي
# الدوري المغربي
# الدوري البرتغالي
# دوري نجوم قطر
# الدوري الإماراتي

# %%
matche_deatails=[]
for i in range(len(matches)):
    teamA=matches[i].find('div',{'class':'teamA'}).text.strip()
    teamB=matches[i].find('div',{'class':'teamB'}).text.strip()
    results=matches[i].find('div',{'class':'MResult'}).find_all('span',{'class':'score'})
    score=f'{results[0].text.strip()} - {results[1].text.strip()}'
    time=matches[i].find('div',{'class':'MResult'}).find('span',{'class':'time'}).text.strip()
    channel=matches[i].find('div',{'class':"channel"}).text.strip()
    print(teamA, score,teamB ,time ,channel)
# Out:
# إيطاليا 82 - 87 الدومينيكان 11:00 بى ان سبورت 4 HD
# أستراليا 82 - 85 ألمانيا 11:30 بى ان سبورت 3 HD
# الجبل الاسود 89 - 74 مصر 11:45 بى ان سبورت 1HD
# لبنان 73 - 128 كندا 12:45 بى ان سبورت 6 HD
# الفلبين 70 - 80 أنجولا 15:00 بى ان سبورت 1HD
# اليابان 98 - 88 فنلندا 15:10 بى ان سبورت HD
# ليتوانيا 96 - 66 المكسيك 15:30 بى ان سبورت 7 HD
# فرنسا 86 - 88 لاتفيا 16:30 بى ان سبورت 5 HD

# %%
matches[4]
# Out:
# <li class="item finish" livescorematchid="89828">
# <a href="/fiba-basketball-world-cup/2819/match/89828/%d8%a7%d9%84%d9%81%d9%84%d8%a8%d9%8a%d9%86-%d8%a3%d9%86%d8%ac%d9%88%d9%84%d8%a7-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails" title="تفاصيل المباراة">
# <div class="allData">
# <!-- Match Top Data -->
# <div class="channel icon-channel">بى ان سبورت 1HD</div>
# <!--Time & Status-->
# <div class="topData">
# <div class="date">الجولة الثانية</div>
# <div class="matchStatus">
# <span>انتهت</span>
# </div>
# </div>
# <!--Teams-->
# <div class="teamCntnr">
# <div class="teamsData">
# <!-- Team A -->
# <div class="teams teamA">
# <img alt="الفلبين" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2023\8\16\philippines12023_8_16_22_19.jpg"/>
# <p>الفلبين</p>
# </div>
# <!-- Match Result -->
# <div class="MResult">
# <span class="score">70</span>
# <span>-</span>
# <span class="score">80</span>
# <span class="time">15:00</span>
# </div>
# <!-- Team B -->
# <div class="teams teamB">
# <img alt="أنجولا" onerror="this.onerror=null;this.src='https://media.gemini.media/img/yallakora/IOSTeams/YK-Generic-team-logo.png'" src="https://media.gemini.media/img/yallakora/IOSTeams//120/\2022\8\3\angola12022_8_3_19_38.jpg"/>
# <p>أنجولا</p>
# </div>
# </div>
# </div>
# </div>
# </a>
# <div class="leftCol">
# <a class="button details" href="/fiba-basketball-world-cup/2819/match/89828/%d8%a7%d9%84%d9%81%d9%84%d8%a8%d9%8a%d9%86-%d8%a3%d9%86%d8%ac%d9%88%d9%84%d8%a7-%d9%83%d8%a3%d8%b3-%d8%a7%d9%84%d8%b9%d8%a7%d9%84%d9%85-%d9%84%d9%83%d8%b1%d8%a9-%d8%a7%d9%84%d8%b3%d9%84%d8%a9#MC_MatcheDetails">التفاصيل</a>
# </div>
# </li>

# %%
matches=championships[0].contents[3].find_all('li')

# %%
for i in range(len(championships)):
    matches_file = open("myfile.txt","a")
    print(championships[i].contents[1].find('h2').text.strip())
    matches = championships[i].contents[3].find_all('li')
    for j in range(len(matches)):
        teamA = matches[j].find('div', {'class':'teamA'}).text.strip()
        teamB = matches[j].find('div', {'class':'teamB'}).text.strip()

        results = matches[j].find('div', {'class':'MResult'}).find_all('span', {'class':'score'})
        score = f'{results[0].text.strip()} - {results[1].text.strip()}'

        time = matches[j].find('div', {'class':'MResult'}).find('span', {'class':'time'}).text.strip()

        print(teamA, teamB, score, time)
# Out:
# كأس العالم لكرة السلة
# إيطاليا الدومينيكان 82 - 87 11:00
# أستراليا ألمانيا 82 - 85 11:30
# الجبل الاسود مصر 89 - 74 11:45
# لبنان كندا 73 - 128 12:45
# الفلبين أنجولا 70 - 80 15:00
# اليابان فنلندا 98 - 88 15:10
# ليتوانيا المكسيك 96 - 66 15:30
# فرنسا لاتفيا 86 - 88 16:30
# الدوري الإنجليزي
# بيرنلي استون فيلا 1 - 3 16:00
# شيفيلد يونايتد مانشستر سيتي 1 - 2 16:00
# نيوكاسل ليفربول 1 - 2 18:30
# الدوري الإسباني
# فياريال برشلونة 3 - 4 18:30
# فالنسيا أوساسونا 1 - 1 20:30
# اتليتك بلباو ريال بيتيس 0 - 0 22:30
# البطولة العربية للأندية لكرة اليد
# الهدى السعودي وفاق عين التوتة 34 - 32 13:00
# الحشد الرياضي العراقي العربي الكويتي 33 - 32 15:00
# مضر السعودي البنك الأهلي 28 - 29 17:00
# الزمالك نادي الكويت 30 - 31 19:30
# الدوري الإيطالي
# يوفنتوس بولونيا 1 - 1 19:30
# فيورنتينا ليتشي 2 - 2 19:30
# لاتسيو جنوى 0 - 1 21:45
# نابولي ساسولو 1 - 0 21:45
# الدوري الألماني
# ماينز آ. فرانكفورت 1 - 1 16:30
# بايرن ميونيخ أوجسبورج 3 - 1 18:30
# الدوري الفرنسي
# رين لوهافر 2 - 2 14:00
# مونبيليه ريمس 1 - 3 16:00
# ستراسبورج تولوز 2 - 0 16:00
# كليرمونت ميتز 0 - 1 16:00
# لوريان ليل 4 - 1 18:05
# نيس ليون 0 - 0 21:45
# دوري أبطال إفريقيا
# سان جورج كي إم كي إم 3 - 1 16:00
# الكونفيدرالية الإفريقية
# جيه.كيه.يو سينجيدا بيج ستارز 2 - 0 19:30
# الدوري التركي
# قيصري سبور سامسون سبور 2 - 1 19:15
# فاتح كاراجومروك أنقرة جوتشو 1 - 1 19:15
# ألانيا سبور هاتاي سبور 0 - 0 21:45
# الدوري التونسي
# اتحاد تطاوين الترجى الرياضي 1 - 1 18:30
# مستقبل المرسى الصفاقســــي 0 - 1 18:30
# البنزرتي الإتحاد المنستيري 0 - 2 18:30
# الدوري المغربي
# اتحاد طنجة الشباب الرياضي السالمي 0 - 2 19:00
# يوسفية برشيد الرجاء البيضاوي 1 - 1 21:15
# نهضة بركان مولودية وجدة - - - 23:30
# الدوري البرتغالي
# بوافيستا كازا بيا 1 - 1 17:30
# فيتوريا جيماريش فيزيلا 2 - 0 20:00
# سبورتينج لشبونة فاماليكاو - - - 22:30
# دوري نجوم قطر
# العربي ام صلال 1 - 1 18:30
# الوكرة الشمال 1 - 2 20:30
# الدوري الإماراتي
# شباب الأهلي خورفكان 2 - 1 17:00
# الشــارقة الوصل 1 - 3 19:30

# %%
for i in range(len(championships)):
    matches_file = open("myfile.txt","a")
    print(championships[i].contents[1].find('h2').text.strip())
    matches = championships[i].contents[3].find_all('li')
    for j in range(len(matches)):
        teamA = matches[j].find('div', {'class':'teamA'}).text.strip()
        teamB = matches[j].find('div', {'class':'teamB'}).text.strip()

        results = matches[j].find('div', {'class':'MResult'}).find_all('span', {'class':'score'})
        score = f'{results[0].text.strip()} - {results[1].text.strip()}'

        time = matches[j].find('div', {'class':'MResult'}).find('span', {'class':'time'}).text.strip()
        try:
            channel = matches[j].find('div', {'class':"channel"}).text.strip()
            print(teamA , teamB , channel)
        except:
            print('There is no channel',teamA,teamB,)
# Out:
# كأس العالم لكرة السلة
# إيطاليا الدومينيكان بى ان سبورت 4 HD
# أستراليا ألمانيا بى ان سبورت 3 HD
# الجبل الاسود مصر بى ان سبورت 1HD
# لبنان كندا بى ان سبورت 6 HD
# الفلبين أنجولا بى ان سبورت 1HD
# اليابان فنلندا بى ان سبورت HD
# ليتوانيا المكسيك بى ان سبورت 7 HD
# فرنسا لاتفيا بى ان سبورت 5 HD
# الدوري الإنجليزي
# بيرنلي استون فيلا بى ان سبورت بريميوم 2
# شيفيلد يونايتد مانشستر سيتي بى ان سبورت بريميوم 1
# نيوكاسل ليفربول بى ان سبورت بريميوم 1
# الدوري الإسباني
# فياريال برشلونة بى ان سبورت 1HD
# فالنسيا أوساسونا بى ان سبورت 4 HD
# اتليتك بلباو ريال بيتيس بى ان سبورت 1HD
# البطولة العربية للأندية لكرة اليد
# There is no channel الهدى السعودي وفاق عين التوتة
# There is no channel الحشد الرياضي العراقي العربي الكويتي
# There is no channel مضر السعودي البنك الأهلي
# الزمالك نادي الكويت الاتحاد العربي لكرة اليد Youtube
# الدوري الإيطالي
# يوفنتوس بولونيا Starz Play App
# فيورنتينا ليتشي Starz Play App
# لاتسيو جنوى Starz Play App
# نابولي ساسولو Starz Play App
# الدوري الألماني
# ماينز آ. فرانكفورت بى ان سبورت اكسترا 1
# بايرن ميونيخ أوجسبورج بى ان سبورت 3 HD
# الدوري الفرنسي
# رين لوهافر بى ان سبورت 2 HD
# مونبيليه ريمس بى ان سبورت 4 HD
# ستراسبورج تولوز بى ان سبورت 6 HD
# كليرمونت ميتز بى ان سبورت 3 HD
# لوريان ليل بى ان سبورت 2 HD
# نيس ليون بى ان سبورت 3 HD
# دوري أبطال إفريقيا
# There is no channel سان جورج كي إم كي إم
# الكونفيدرالية الإفريقية
# There is no channel جيه.كيه.يو سينجيدا بيج ستارز
# الدوري التركي
# قيصري سبور سامسون سبور بى ان سبورت تركيا
# فاتح كاراجومروك أنقرة جوتشو بى ان سبورت تركيا
# ألانيا سبور هاتاي سبور بى ان سبورت تركيا
# الدوري التونسي
# There is no channel اتحاد تطاوين الترجى الرياضي
# There is no channel مستقبل المرسى الصفاقســــي
# There is no channel البنزرتي الإتحاد المنستيري
# الدوري المغربي
# There is no channel اتحاد طنجة الشباب الرياضي السالمي
# There is no channel يوسفية برشيد الرجاء البيضاوي
# There is no channel نهضة بركان مولودية وجدة
# الدوري البرتغالي
# There is no channel بوافيستا كازا بيا
# There is no channel فيتوريا جيماريش فيزيلا
# There is no channel سبورتينج لشبونة فاماليكاو
# دوري نجوم قطر
# There is no channel العربي ام صلال
# There is no channel الوكرة الشمال
# الدوري الإماراتي
# There is no channel شباب الأهلي خورفكان
# There is no channel الشــارقة الوصل
